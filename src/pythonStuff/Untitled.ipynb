# %%
import json

# %%
f = open('test2.json')

data = json.load(f)
data
# Out:
# {'meta': {'version': 1,
#   'code': 200,
#   'request': 'http://nba.cloud/games/0042200311/boxscore?Format=json',
#   'time': '2023-05-16 23:37:12.905760'},
#  'game': {'gameId': '0042200311',
#   'gameTimeLocal': '2023-05-16T18:30:00-06:00',
#   'gameTimeUTC': '2023-05-17T00:30:00Z',
#   'gameTimeHome': '2023-05-16T18:30:00-06:00',
#   'gameTimeAway': '2023-05-16T17:30:00-07:00',
#   'gameEt': '2023-05-16T20:30:00-04:00',
#   'duration': 155,
#   'gameCode': '20230516/LALDEN',
#   'gameStatusText': 'Final',
#   'gameStatus': 3,
#   'regulationPeriods': 4,
#   'period': 4,
#   'gameClock': 'PT00M00.00S',
#   'attendance': 19633,
#   'sellout': '1',
#   'arena': {'arenaId': 1000046,
#    'arenaName': 'Ball Arena',
#    'arenaCity': 'Denver',
#    'arenaState': 'CO',
#    'arenaCountry': 'US',
#    'arenaTimezone': 'America/Denver'},
#   'officials': [{'personId': 2003,
#     'name': 'Pat Fraher',
#     'nameI': 'P. Fraher',
#     'firstName': 'Pat',
#     'familyName': 'Fraher',
# ...

# %%
f = open('test.json')

data = json.load(f)
data
# Out:
# {'meta': {'version': 1,
#   'code': 200,
#   'request': 'http://nba.cloud/games/0042200311/boxscore?Format=json',
#   'time': '2023-05-16 21:59:12.996164'},
#  'game': {'gameId': '0042200311',
#   'gameTimeLocal': '2023-05-16T18:30:00-06:00',
#   'gameTimeUTC': '2023-05-17T00:30:00Z',
#   'gameTimeHome': '2023-05-16T18:30:00-06:00',
#   'gameTimeAway': '2023-05-16T17:30:00-07:00',
#   'gameEt': '2023-05-16T20:30:00-04:00',
#   'duration': 61,
#   'gameCode': '20230516/LALDEN',
#   'gameStatusText': 'Half',
#   'gameStatus': 2,
#   'regulationPeriods': 4,
#   'period': 2,
#   'gameClock': 'PT00M00.00S',
#   'attendance': 0,
#   'sellout': '0',
#   'arena': {'arenaId': 1000046,
#    'arenaName': 'Ball Arena',
#    'arenaCity': 'Denver',
#    'arenaState': 'CO',
#    'arenaCountry': 'US',
#    'arenaTimezone': 'America/Denver'},
#   'officials': [{'personId': 2003,
#     'name': 'Pat Fraher',
#     'nameI': 'P. Fraher',
#     'firstName': 'Pat',
#     'familyName': 'Fraher',
# ...
